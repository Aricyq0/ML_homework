# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import math

'''创建实例数据集'''
def createDataSet1():    # 创造示例数据
    dataSet = [['<=30','high','no','fair','no'],
               ['<=30','high','no','excellent','no'],
               ['[31,40]','high','no','fair','yes'],
               ['>40','medium','no','fair','yes'],
               ['>40','low','yes','fair','yes'],
               ['>40','low','yes','excellent','no'],
               ['[31,40]','low','yes','excellent','yes'],
               ['<=30','medium','no','fair','no'],
               ['<=30','low','yes','fair','yes'],
               ['>40','medium','yes','fair','yes'],
               ['<=30','medium','yes','excellent','yes'],
               ['[31,40]','medium','no','excellent','yes'],
               ['[31,40]','high','yes','fair','yes']               ]
    labels = ['Age','Incoming','Student',"Credit Rating"]
    return dataSet,labels

'''计算熵'''
def calcEntropy(dataSet):
    numFeatures = len(dataSet[0])
    #print('属性或特征个数 =', numFeatures)
    numDataSet = len(dataSet)
    #print('数据集长度 =', numDataset)
    typeCount = {}
    # pi = ni / n; ni:第i类样本数；n:总样本数
    # 遍历每行，统计不同类别出现次数
    for row in dataSet:
        if row[-1] not in typeCount.keys():
            typeCount[row[-1]] = 0   # row[-1]为类别，若类别还没统计过，加入字典，出现次数为0,后面+1
        typeCount[row[-1]] += 1      # 若类别统计过，出现次数+1
    print('每类样本出现个数', typeCount)
    
    entropy = 0.0 # 熵
    for num in typeCount.values():
        p = num / numDataSet
        entropy -= p * math.log(p,2)
    print('entropy =', entropy)
    return entropy

'''选择最优的分类特征'''
def chooseBestFeatureToSplit(dataSet):
    numFeatures = len(dataSet[0]) - 1 # 不算最后一列,那是类别：男女
    baseEntropy = calcEntropy(dataSet) #原始的信息熵
    bestInfoGain = 0          # 信息增益
    bestFeatIndex = -1     # 最优特征下标
    for i in range(numFeatures):
        featList = [row[i] for row in dataSet]# 第i列，特征组成的列表
        uniqueFeatValues = set(featList)   # 用集合去重，得到特征值，如{'短', '长'}
        
        newEntropy = 0
        for value in uniqueFeatValues:     # 用特征值中的每一个 划分数据集
            subDataSet = splitDataSet(dataSet,i,value)
            print('划分后的子集 :',subDataSet)
            weight = len(subDataSet)/float(len(dataSet))# 权重，子集个数/ 全集个数
            newEntropy += weight * calcEntropy(subDataSet) # 按某个特征分类后的熵 = 累加 子集熵*weight
        print('划分后的信息熵 :', newEntropy)
        infoGain = baseEntropy - newEntropy # 信息增益， 越大越好
        if infoGain > bestInfoGain: 
            bestInfoGain = infoGain
            bestFeatIndex = i
    return bestFeatIndex

'''
划分数据集
axis : 最优特征BestFeature(BF)所在下标
value : BF能取得值
'''
def splitDataSet(dataSet, axis, value): # 按某个特征分类后的数据
    retDataSet = []
    for row in dataSet:
        if  row[axis] == value:
            reducedFeatvec = row[:axis]         # 取出分裂特征前的数据集
            reducedFeatvec.extend(row[axis+1:]) # 取出分裂特征后的数据集,合并两部分数据集
            retDataSet.append(reducedFeatvec)   # 本行取得的去除value的列表 加入总列表
    return retDataSet

'''统计，多者胜出'''
def majorityCnt(typeList):    #按分类后类别数量排序，比如：最后分类为2男1女，则判定为男；
    typeCount={}
    for t in typeList:
        if t not in typeCount.keys():
            typeCount[t] = 0
        typeCount[t] += 1
    print('typeCount =', typeCount)
    sortedTypeCount = sorted(typeCount.items(),key=lambda x:x[1],reverse=True)# 从大到小排列，结果如[('女', 2), ('男', 1)]
    print('少数服从多数，多数为 :',sortedTypeCount[0][0])
    return sortedTypeCount[0][0]

'''递归建树'''
def createTree(dataSet, labels):
    typeList = [row[-1] for row in dataSet]  # 类别：男或女
    if typeList.count(typeList[0]) == len(typeList):# 若只有一个类，直接返回
        return typeList[0]
    if len(dataSet[0]) == 1:  # 若最后只剩下一个类别属性
        return majorityCnt(typeList)
    bestFeatIndex = chooseBestFeatureToSplit(dataSet) # 最优特征下标和对应特征
    print('***********************************',bestFeatIndex,labels)

    bestFeat = labels[bestFeatIndex]
    print('bestFeatureIndex =', bestFeatIndex)
    print('***********最优特征值 =', bestFeat, end='***********\n')
    
    myTree={bestFeat:{}} # 分类结果以字典形式保存
    del(labels[bestFeatIndex])
    
    uniqueVals = set() # 最优特征能取的值，用set保证无重复
    {uniqueVals.add(row[bestFeatIndex]) for row in dataSet}
    print(f'{bestFeat} 能取的值 :',uniqueVals)
    for value in uniqueVals:
        subLabels = labels # labels里已经删去了最优特征，用subLabels为了区分更明显
        myTree[bestFeat][value] = createTree(splitDataSet(dataSet,bestFeatIndex,value), subLabels)
    return myTree

if __name__=='__main__':
    dataset, labels = createDataSet1()
    print(createTree(dataset, labels))  # 输出决策树模型结果
# Out:
# 每类样本出现个数 {'no': 4, 'yes': 9}
# entropy = 0.8904916402194913
# 划分后的子集 : [['medium', 'no', 'fair', 'yes'], ['low', 'yes', 'fair', 'yes'], ['low', 'yes', 'excellent', 'no'], ['medium', 'yes', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 3, 'no': 1}
# entropy = 0.8112781244591328
# 划分后的子集 : [['high', 'no', 'fair', 'no'], ['high', 'no', 'excellent', 'no'], ['medium', 'no', 'fair', 'no'], ['low', 'yes', 'fair', 'yes'], ['medium', 'yes', 'excellent', 'yes']]
# 每类样本出现个数 {'no': 3, 'yes': 2}
# entropy = 0.9709505944546686
# 划分后的子集 : [['high', 'no', 'fair', 'yes'], ['low', 'yes', 'excellent', 'yes'], ['medium', 'no', 'excellent', 'yes'], ['high', 'yes', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 4}
# entropy = 0.0
# 划分后的信息熵 : 0.6230665746238365
# 划分后的子集 : [['<=30', 'no', 'fair', 'no'], ['<=30', 'no', 'excellent', 'no'], ['[31,40]', 'no', 'fair', 'yes'], ['[31,40]', 'yes', 'fair', 'yes']]
# 每类样本出现个数 {'no': 2, 'yes': 2}
# entropy = 1.0
# 划分后的子集 : [['>40', 'no', 'fair', 'yes'], ['<=30', 'no', 'fair', 'no'], ['>40', 'yes', 'fair', 'yes'], ['<=30', 'yes', 'excellent', 'yes'], ['[31,40]', 'no', 'excellent', 'yes']]
# 每类样本出现个数 {'yes': 4, 'no': 1}
# entropy = 0.7219280948873623
# 划分后的子集 : [['>40', 'yes', 'fair', 'yes'], ['>40', 'yes', 'excellent', 'no'], ['[31,40]', 'yes', 'excellent', 'yes'], ['<=30', 'yes', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 3, 'no': 1}
# entropy = 0.8112781244591328
# 划分后的信息熵 : 0.8349809978671803
# 划分后的子集 : [['>40', 'low', 'fair', 'yes'], ['>40', 'low', 'excellent', 'no'], ['[31,40]', 'low', 'excellent', 'yes'], ['<=30', 'low', 'fair', 'yes'], ['>40', 'medium', 'fair', 'yes'], ['<=30', 'medium', 'excellent', 'yes'], ['[31,40]', 'high', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 6, 'no': 1}
# entropy = 0.5916727785823275
# 划分后的子集 : [['<=30', 'high', 'fair', 'no'], ['<=30', 'high', 'excellent', 'no'], ['[31,40]', 'high', 'fair', 'yes'], ['>40', 'medium', 'fair', 'yes'], ['<=30', 'medium', 'fair', 'no'], ['[31,40]', 'medium', 'excellent', 'yes']]
# 每类样本出现个数 {'no': 3, 'yes': 3}
# entropy = 1.0
# 划分后的信息熵 : 0.7801314961597148
# 划分后的子集 : [['<=30', 'high', 'no', 'no'], ['[31,40]', 'high', 'no', 'yes'], ['>40', 'medium', 'no', 'yes'], ['>40', 'low', 'yes', 'yes'], ['<=30', 'medium', 'no', 'no'], ['<=30', 'low', 'yes', 'yes'], ['>40', 'medium', 'yes', 'yes'], ['[31,40]', 'high', 'yes', 'yes']]
# 每类样本出现个数 {'no': 2, 'yes': 6}
# entropy = 0.8112781244591328
# 划分后的子集 : [['<=30', 'high', 'no', 'no'], ['>40', 'low', 'yes', 'no'], ['[31,40]', 'low', 'yes', 'yes'], ['<=30', 'medium', 'yes', 'yes'], ['[31,40]', 'medium', 'no', 'yes']]
# 每类样本出现个数 {'no': 2, 'yes': 3}
# entropy = 0.9709505944546686
# 划分后的信息熵 : 0.8726906129189543
# *********************************** 0 ['Age', 'Incoming', 'Student', 'Credit Rating']
# bestFeatureIndex = 0
# ***********最优特征值 = Age***********
# Age 能取的值 : {'>40', '<=30', '[31,40]'}
# 每类样本出现个数 {'yes': 3, 'no': 1}
# entropy = 0.8112781244591328
# 划分后的子集 : [['no', 'fair', 'yes'], ['yes', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 2}
# entropy = 0.0
# 划分后的子集 : [['yes', 'fair', 'yes'], ['yes', 'excellent', 'no']]
# 每类样本出现个数 {'yes': 1, 'no': 1}
# entropy = 1.0
# 划分后的信息熵 : 0.5
# 划分后的子集 : [['low', 'fair', 'yes'], ['low', 'excellent', 'no'], ['medium', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 2, 'no': 1}
# entropy = 0.9182958340544896
# 划分后的子集 : [['medium', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 1}
# entropy = 0.0
# 划分后的信息熵 : 0.6887218755408672
# 划分后的子集 : [['medium', 'no', 'yes'], ['low', 'yes', 'yes'], ['medium', 'yes', 'yes']]
# 每类样本出现个数 {'yes': 3}
# entropy = 0.0
# 划分后的子集 : [['low', 'yes', 'no']]
# 每类样本出现个数 {'no': 1}
# entropy = 0.0
# 划分后的信息熵 : 0.0
# *********************************** 2 ['Incoming', 'Student', 'Credit Rating']
# bestFeatureIndex = 2
# ***********最优特征值 = Credit Rating***********
# Credit Rating 能取的值 : {'fair', 'excellent'}
# 每类样本出现个数 {'no': 3, 'yes': 2}
# entropy = 0.9709505944546686
# 划分后的子集 : [['no', 'fair', 'no'], ['no', 'excellent', 'no']]
# 每类样本出现个数 {'no': 2}
# entropy = 0.0
# 划分后的子集 : [['no', 'fair', 'no'], ['yes', 'excellent', 'yes']]
# 每类样本出现个数 {'no': 1, 'yes': 1}
# entropy = 1.0
# 划分后的子集 : [['yes', 'fair', 'yes']]
# 每类样本出现个数 {'yes': 1}
# entropy = 0.0
# 划分后的信息熵 : 0.4
# 划分后的子集 : [['low', 'fair', 'yes'], ['medium', 'excellent', 'yes']]
# 每类样本出现个数 {'yes': 2}
# entropy = 0.0
# 划分后的子集 : [['high', 'fair', 'no'], ['high', 'excellent', 'no'], ['medium', 'fair', 'no']]
# 每类样本出现个数 {'no': 3}
# entropy = 0.0
# 划分后的信息熵 : 0.0
# 划分后的子集 : [['high', 'no', 'no'], ['medium', 'no', 'no'], ['low', 'yes', 'yes']]
# 每类样本出现个数 {'no': 2, 'yes': 1}
# entropy = 0.9182958340544896
# 划分后的子集 : [['high', 'no', 'no'], ['medium', 'yes', 'yes']]
# 每类样本出现个数 {'no': 1, 'yes': 1}
# entropy = 1.0
# 划分后的信息熵 : 0.9509775004326937
# *********************************** 1 ['Incoming', 'Student']
# bestFeatureIndex = 1
# ***********最优特征值 = Student***********
# Student 能取的值 : {'yes', 'no'}
# {'Age': {'>40': {'Credit Rating': {'fair': 'yes', 'excellent': 'no'}}, '<=30': {'Student': {'yes': 'yes', 'no': 'no'}}, '[31,40]': 'yes'}}
